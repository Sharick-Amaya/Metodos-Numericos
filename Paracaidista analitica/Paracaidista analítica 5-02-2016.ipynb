# %%
g=9.8
m=68.1
c=12.5
e=2.7
t=0

print "\tt\t|\tV(t)"
print "-------------------------------------"
while t<=110 :
    V=((g*m)/c)*(1-e**(-(c/m)*t))
    print "\t%d\t|\t%f" % (t, V)
    t+=1
# Out:
# 	t	|	V(t)
# -------------------------------------
# 	0	|	0.000000
# 	1	|	8.898105
# 	2	|	16.313242
# 	3	|	22.492564
# 	4	|	27.642033
# 	5	|	31.933285
# 	6	|	35.509353
# 	7	|	38.489429
# 	8	|	40.972842
# 	9	|	43.042366
# 	10	|	44.766981
# 	11	|	46.204170
# 	12	|	47.401836
# 	13	|	48.399897
# 	14	|	49.231620
# 	15	|	49.924727
# 	16	|	50.502320
# 	17	|	50.983651
# 	18	|	51.384762
# 	19	|	51.719024
# 	20	|	51.997578
# 	21	|	52.229707
# 	22	|	52.423149
# 	23	|	52.584352
# 	24	|	52.718689
# 	25	|	52.830637
# 	26	|	52.923928
# 	27	|	53.001671
# 	28	|	53.066457
# 	29	|	53.120446
# 	30	|	53.165437
# 	31	|	53.202929
# 	32	|	53.234173
# 	33	|	53.260210
# 	34	|	53.281908
# 	35	|	53.299989
# 	36	|	53.315057
# 	37	|	53.327614
# 	38	|	53.338078
# 	39	|	53.346798
# 	40	|	53.354065
# 	41	|	53.360120
# 	42	|	53.365167
# 	43	|	53.369372
# 	44	|	53.372877
# 	45	|	53.375797
# 	46	|	53.378231
# 	47	|	53.380259
# 	48	|	53.381949
# 	49	|	53.383358
# 	50	|	53.384531
# 	51	|	53.385509
# 	52	|	53.386324
# ...
