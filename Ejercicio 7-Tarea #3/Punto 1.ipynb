# %% [markdown]
# ## 1. Implementar el metodo de la falsa posicion.

# %%
def funcion(c):
    g = 9.8
    m = 68.1
    e = 2.71
    v = 40
    t = 10
    
    return ((g*m/c)*(1-e**(-(c/m)*t))-v)

xl = 12
xu = 20
xr = 0
ter = 0

print ("---------------------------------------------------------------------------------")
print ("|Término|       Xu       |       Xl       |       Xr       |        F(xr)       |")
print ("---------------------------------------------------------------------------------")
while True:
    ter += 1
    if (xr!=0):
        print ("|   %d\t|   %f    |   %f    |   %f    |     %f\t|" %(ter, xu, xl, xr, funcion(xr)))
        print ("---------------------------------------------------------------------------------")        
    else :
        print ("|   %d\t|   %f    |   %f    |   %f     |       -----        |" %(ter, xu, xl, xr))
        print ("---------------------------------------------------------------------------------")       
    if (funcion(xl)*funcion(xu)<0):
        xr = xu-((funcion(xu)*(xl-xu))/(funcion(xl)-funcion(xu)))
        if (funcion(xl)*funcion(xr)<0):
            xu = xr
            continue
        if (funcion(xl)*funcion(xr)>0):
            xl = xr
            continue
        if (funcion(xl)*funcion(xr)==0):
            print("")
            print ("LA RAIZ ESTA EN  t = %f" %(xr))
            break
    else:
        break
# Out:
# ---------------------------------------------------------------------------------
# |Término|       Xu       |       Xl       |       Xr       |        F(xr)       |
# ---------------------------------------------------------------------------------
# |   1	|   20.000000    |   12.000000    |   0.000000     |       -----        |
# ---------------------------------------------------------------------------------
# |   2	|   15.334508    |   12.000000    |   15.334508    |     -1.089167	|
# ---------------------------------------------------------------------------------
# |   3	|   14.823314    |   12.000000    |   14.823314    |     -0.117933	|
# ---------------------------------------------------------------------------------
# |   4	|   14.769028    |   12.000000    |   14.769028    |     -0.012502	|
# ---------------------------------------------------------------------------------
# |   5	|   14.763285    |   12.000000    |   14.763285    |     -0.001322	|
# ---------------------------------------------------------------------------------
# |   6	|   14.762677    |   12.000000    |   14.762677    |     -0.000140	|
# ---------------------------------------------------------------------------------
# |   7	|   14.762613    |   12.000000    |   14.762613    |     -0.000015	|
# ---------------------------------------------------------------------------------
# |   8	|   14.762606    |   12.000000    |   14.762606    |     -0.000002	|
# ---------------------------------------------------------------------------------
# |   9	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   10	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   11	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   12	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   13	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   14	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   15	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   16	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   17	|   14.762606    |   12.000000    |   14.762606    |     -0.000000	|
# ---------------------------------------------------------------------------------
# |   18	|   14.762606    |   14.762606    |   14.762606    |     0.000000	|
# ---------------------------------------------------------------------------------
#
# LA RAIZ ESTA EN  t = 14.762606
